# %%
iter  = []
x0 = 1
c = 10
e = 10**-3
while True:
    x1 = 0.5*(c/x0 + x0)
    iter.append(x1)
    if x1 - x0 < e:
        print(x1)
        break
    x0 = x1
# Out:
# 3.659090909090909

# %%
print(iter)
print(len(iter))
# Out:
# [5.5, 3.659090909090909]
# 2
